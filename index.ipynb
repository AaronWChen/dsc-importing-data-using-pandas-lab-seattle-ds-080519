# %% [markdown]
# # Importing Data Using Pandas - Lab
#
# ## Introduction
#
# In this lab, you'll get some practice with loading files with summary or metadata, and if you find that easy, the optional "level up" content covers loading data from a corrupted csv file!
#
# ## Objectives
# You will be able to:
# * Import data from csv files and Excel files
# * Understand and explain key arguments for imports
# * Save information to csv and Excel files
# * Access data within a Pandas DataFrame (print() and .head())
#
# ##  Loading Files with Summary or Meta Data
#
# Load either of the files Zipcode_Demos.csv or Zipcode_Demos.xlsx. What's going on with this dataset? Clean it up into a useable format and describe the nuances of how the data is currently formatted.
#
# All data files are stored in a folder titled 'Data'.

# %%
# !pwd
# Out:
# /Users/aaronchen/Projects/dsc0805/Mod01/Section04/dsc-importing-data-using-pandas-lab-seattle-ds-080519

# %%
# Out:
# CONTRIBUTING.md Data            LICENSE.md      README.md       index.ipynb

# %%
# Your code here - Load the file
import numpy as np
import pandas as pd

raw_zipcode_data = pd.read_csv('./Data/Zipcode_Demos.csv')

# %%
# Your code here - Perform exploratory data analysis

# %%
raw_zipcode_data.head()
# Out:
#    0  Average Statistics Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0  1                 NaN          0        NaN        NaN        NaN
# 1  2   JURISDICTION NAME    10005.8        NaN        NaN        NaN
# 2  3  COUNT PARTICIPANTS        9.4        NaN        NaN        NaN
# 3  4        COUNT FEMALE        4.8        NaN        NaN        NaN
# 4  5      PERCENT FEMALE      0.404        NaN        NaN        NaN
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9     ...     Unnamed: 37  \
# 0        NaN        NaN        NaN        NaN     ...             NaN
# 1        NaN        NaN        NaN        NaN     ...             NaN
# 2        NaN        NaN        NaN        NaN     ...             NaN
# 3        NaN        NaN        NaN        NaN     ...             NaN
# 4        NaN        NaN        NaN        NaN     ...             NaN
#
#   Unnamed: 38 Unnamed: 39 Unnamed: 40 Unnamed: 41 Unnamed: 42 Unnamed: 43  \
# 0         NaN         NaN         NaN         NaN         NaN         NaN
# 1         NaN         NaN         NaN         NaN         NaN         NaN
# 2         NaN         NaN         NaN         NaN         NaN         NaN
# 3         NaN         NaN         NaN         NaN         NaN         NaN
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
#   Unnamed: 44 Unnamed: 45 Unnamed: 46
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN
#
# [5 rows x 47 columns]

# %%
raw_zipcode_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 47 columns):
# 0                     57 non-null int64
# Average Statistics    56 non-null object
# Unnamed: 2            57 non-null object
# Unnamed: 3            11 non-null object
# Unnamed: 4            11 non-null object
# Unnamed: 5            11 non-null object
# Unnamed: 6            11 non-null object
# Unnamed: 7            11 non-null object
# Unnamed: 8            11 non-null object
# Unnamed: 9            11 non-null object
# Unnamed: 10           11 non-null object
# Unnamed: 11           11 non-null object
# Unnamed: 12           11 non-null object
# Unnamed: 13           11 non-null object
# Unnamed: 14           11 non-null object
# Unnamed: 15           11 non-null object
# Unnamed: 16           11 non-null object
# Unnamed: 17           11 non-null object
# Unnamed: 18           11 non-null object
# Unnamed: 19           11 non-null object
# Unnamed: 20           11 non-null object
# Unnamed: 21           11 non-null object
# Unnamed: 22           11 non-null object
# Unnamed: 23           11 non-null object
# Unnamed: 24           11 non-null object
# Unnamed: 25           11 non-null object
# Unnamed: 26           11 non-null object
# Unnamed: 27           11 non-null object
# Unnamed: 28           11 non-null object
# Unnamed: 29           11 non-null object
# Unnamed: 30           11 non-null object
# Unnamed: 31           11 non-null object
# Unnamed: 32           11 non-null object
# Unnamed: 33           11 non-null object
# Unnamed: 34           11 non-null object
# Unnamed: 35           11 non-null object
# Unnamed: 36           11 non-null object
# Unnamed: 37           11 non-null object
# Unnamed: 38           11 non-null object
# Unnamed: 39           11 non-null object
# Unnamed: 40           11 non-null object
# Unnamed: 41           11 non-null object
# Unnamed: 42           11 non-null object
# Unnamed: 43           11 non-null object
# Unnamed: 44           11 non-null object
# Unnamed: 45           11 non-null object
# Unnamed: 46           11 non-null object
# dtypes: int64(1), object(46)
# memory usage: 21.0+ KB

# %%
# What is going on with this data set? Anything unusual?

# %% [markdown]
# This data set is mostly empty or nan objects.

# %%
# Your code here - Clean up the data set

# %%
cleaned_zipcode_data = raw_zipcode_data.loc[~raw_zipcode_data['Unnamed: 3'].isna(), :]
cleaned_zipcode_data.T
# Out:
#                                                      46     47     48     49  \
# 0                                                    47     48     49     50
# Average Statistics                    JURISDICTION NAME  10001  10002  10003
# Unnamed: 2                           COUNT PARTICIPANTS     44     35      1
# Unnamed: 3                                 COUNT FEMALE     22     19      1
# Unnamed: 4                               PERCENT FEMALE    0.5   0.54      1
# Unnamed: 5                                   COUNT MALE     22     16      0
# Unnamed: 6                                 PERCENT MALE    0.5   0.46      0
# Unnamed: 7                         COUNT GENDER UNKNOWN      0      0      0
# Unnamed: 8                       PERCENT GENDER UNKNOWN      0      0      0
# Unnamed: 9                           COUNT GENDER TOTAL     44     35      1
# Unnamed: 10                        PERCENT GENDER TOTAL    100    100    100
# Unnamed: 11                      COUNT PACIFIC ISLANDER      0      0      0
# Unnamed: 12                    PERCENT PACIFIC ISLANDER      0      0      0
# Unnamed: 13                       COUNT HISPANIC LATINO     16      1      0
# Unnamed: 14                     PERCENT HISPANIC LATINO   0.36   0.03      0
# Unnamed: 15                       COUNT AMERICAN INDIAN      0      0      0
# Unnamed: 16                     PERCENT AMERICAN INDIAN      0      0      0
# Unnamed: 17                    COUNT ASIAN NON HISPANIC      3     28      1
# Unnamed: 18                  PERCENT ASIAN NON HISPANIC   0.07    0.8      1
# Unnamed: 19                    COUNT WHITE NON HISPANIC      1      6      0
# Unnamed: 20                  PERCENT WHITE NON HISPANIC   0.02   0.17      0
# Unnamed: 21                    COUNT BLACK NON HISPANIC     21      0      0
# Unnamed: 22                  PERCENT BLACK NON HISPANIC   0.48      0      0
# Unnamed: 23                       COUNT OTHER ETHNICITY      3      0      0
# Unnamed: 24                     PERCENT OTHER ETHNICITY   0.07      0      0
# Unnamed: 25                     COUNT ETHNICITY UNKNOWN      0      0      0
# Unnamed: 26                   PERCENT ETHNICITY UNKNOWN      0      0      0
# Unnamed: 27                       COUNT ETHNICITY TOTAL     44     35      1
# Unnamed: 28                     PERCENT ETHNICITY TOTAL    100    100    100
# Unnamed: 29              COUNT PERMANENT RESIDENT ALIEN      2      2      0
# Unnamed: 30            PERCENT PERMANENT RESIDENT ALIEN   0.05   0.06      0
# Unnamed: 31                            COUNT US CITIZEN     42     33      1
# Unnamed: 32                          PERCENT US CITIZEN   0.95   0.94      1
# Unnamed: 36             0      0      0      0      0      0      0
# Unnamed: 37             0      2      6      1      2      0      3
# Unnamed: 38             0    100    100    100    100      0    100
# Unnamed: 39             0      0      0      1      0      0      0
# Unnamed: 40             0      0      0      1      0      0      0
# Unnamed: 41             0      2      6      0      2      0      3
# Unnamed: 42             0      1      1      0      1      0      1
# Unnamed: 43             0      0      0      0      0      0      0
# Unnamed: 44             0      0      0      0      0      0      0
# Unnamed: 45             0      2      6      1      2      0      3
# Unnamed: 46             0    100    100    100    100      0    100

# %% [markdown]
# ## Level Up (Optional) - Loading Corrupt CSV files
#
# Occasionally, you encounter some really ill formatted data. One example of this can be data that has strings containing commas in a csv file. Under the standard protocol, when this occurs, one is supposed to use quotes to differentiate between the commas denoting fields and commas within those fields themselves. For example, we could have a table like this:
#
# ReviewerID,Rating,N_reviews,Review,VenueID
# 123456,4,137,This restaurant was pretty good, we had a great time.,98765
#
# Which should be saved like this if it were a csv (to avoid confusion with the commas in the Review text):
# "ReviewerID","Rating","N_reviews","Review","VenueID"
# "123456","4","137","This restaurant was pretty good, we had a great time.","98765"
#
# Attempt to import the corrupt file, or at least a small preview of it. It is appropriately titled Yelp_Reviews_corrupt.csv. Investigate some of the intricacies of skipping rows to then pass over this error and comment on what you think is going on.

# %%
#Hint: here's a useful programming pattern to use.
try:
    #do something
    corrupt_yelp_data = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
except Exception as e:
    #handle your exception e
    
    corrupt_yelp_data_minus_reviews = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv', usecols=[
        1, 2, 3, 4, 5, 6,8, 9])

# %%
corrupt_yelp_data_minus_reviews.head()
# Out:
#               business_id cool        date funny               review_id  \
# 0  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13     0  dDl8zu1vWPdKGihJrwQbpw
# 1  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23     1  LZp4UX5zK3e-c5ZGSeo3kA
# 2  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05     0  jsDu6QEJHbwP2Blom1PLCA
# 3  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25     0  pfavA0hr3nyqO61oupj-lA
# 4  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15     0  STiFMww2z31siPY7BWNC2g
#
#   stars useful                 user_id
# 0     5      0  msQe1u7Z_XuqjGoqhB0J5g
# 1     1      3  msQe1u7Z_XuqjGoqhB0J5g
# 2     5      0  msQe1u7Z_XuqjGoqhB0J5g
# 3     1      2  msQe1u7Z_XuqjGoqhB0J5g
# 4     5      0  TlvV-xJhmh7LCwJYXkV-cg

# %%
corrupt_yelp_data = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-21-17633e4e0567> in <module>()
# ----> 1 corrupt_yelp_data = pd.read_csv('./Data/Yelp_Reviews_Corrupt.csv')
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     444
#     445     try:
# --> 446         data = parser.read(nrows)
#     447     finally:
#     448         parser.close()
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1034                 raise ValueError('skipfooter not supported for iteration')
#    1035
# -> 1036         ret = self._engine.read(nrows)
#    1037
#    1038         # May alter columns / col_dict
#
# //anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/parsers.py in read(self, nrows)
#    1846     def read(self, nrows=None):
#    1847         try:
# -> 1848             data = self._reader.read(nrows)
#    1849         except StopIteration:
#    1850             if self._first_chunk:
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 10 fields in line 2331, saw 11

# %% [markdown]
# ## Summary
#
# Congratulations, you now practiced your pandas-importing skills!
